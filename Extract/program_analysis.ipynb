# %%
# %run ExtractAPI.ipynb
# Out:
# DF created: 0 - https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/a6f7a8e8-e497-4f77-9881-daba429ea981/download/approved-operating-budget-summary-2023.xlsx
# DF created: 1 - https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/9e5f9a63-fdeb-46e4-9f5f-8143038de56d/download/approved-operating-budget-summary-2022.xlsx
# Sheetname not found: 2014
# Sheetname not found: 2015
# Sheetname not found: 2016
# Sheetname not found: 2017
# Sheetname not found: 2018
# Sheetname not found: 2019
# Sheetname not found: 2020
# DF created: 2 - https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/930502fa-87f1-4d71-8b71-4435df594b38/download/2021-open-data2.xlsx
# DF created: 3 - https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/4e58558a-4773-4cd0-a16a-de481f25cb4d/download/2020-operating-open-data.xlsx
# ...

# %%
pandl_2014 = pd.DataFrame()
pandl_2015 = pd.DataFrame()
pandl_2016 = pd.DataFrame()
pandl_2017 = pd.DataFrame()
pandl_2018 = pd.DataFrame()

pandl_2019 = pd.DataFrame()
pandl_2020 = pd.DataFrame()
pandl_2021 = pd.DataFrame()
pandl_2022 = pd.DataFrame()
pandl_2023 = pd.DataFrame()

# 2014
pandl_2014["rev"] = budget2014_df_rev.groupby("Program")["Budgeted amount 2014"].sum().abs()
pandl_2014["exp"] = budget2014_df_exp.groupby("Program")["Budgeted amount 2014"].sum()
pandl_2014["res-2014"] = pandl_2014["rev"] - pandl_2014["exp"]
pandl_2014.insert(0, 'Program', pandl_2014.index)

# 2015
pandl_2015["rev"] = budget2015_df_rev.groupby("Program")["Budgeted amount 2015"].sum().abs()
pandl_2015["exp"] = budget2015_df_exp.groupby("Program")["Budgeted amount 2015"].sum()
pandl_2015["res-2015"] = pandl_2015["rev"] - pandl_2015["exp"]
pandl_2015.insert(0, 'Program', pandl_2015.index)

# 2016
pandl_2016["rev"] = budget2016_df_rev.groupby("Program")["Budgeted amount 2016"].sum().abs()
pandl_2016["exp"] = budget2016_df_exp.groupby("Program")["Budgeted amount 2016"].sum()
pandl_2016["res-2016"] = pandl_2016["rev"] - pandl_2016["exp"]
pandl_2016.insert(0, 'Program', pandl_2016.index)

# 2017
pandl_2017["rev"] = budget2017_df_rev.groupby("Program")["Budgeted amount 2017"].sum().abs()
pandl_2017["exp"] = budget2017_df_exp.groupby("Program")["Budgeted amount 2017"].sum()
pandl_2017["res-2017"] = pandl_2017["rev"] - pandl_2017["exp"]
pandl_2017.insert(0, 'Program', pandl_2017.index)

# 2018
pandl_2018["rev"] = budget2018_df_rev.groupby("Program")["Budgeted amount 2018"].sum().abs()
pandl_2018["exp"] = budget2018_df_exp.groupby("Program")["Budgeted amount 2018"].sum()
pandl_2018["res-2018"] = pandl_2018["rev"] - pandl_2018["exp"]
pandl_2018.insert(0, 'Program', pandl_2018.index)
 
#2019
pandl_2019["rev"] = budget2019_df_rev.groupby("Program")["Budgeted amount 2019"].sum().abs()
pandl_2019["exp"] = budget2019_df_exp.groupby("Program")["Budgeted amount 2019"].sum()
pandl_2019["res-2019"] = pandl_2019["rev"] - pandl_2019["exp"]
pandl_2019.insert(0, 'Program', pandl_2019.index)
#pandl_2019 = pandl_2019.drop(columns=["rev", "exp"])

#2020
pandl_2020["rev"] = budget2020_df_rev.groupby("Program")["Budgeted amount 2020"].sum().abs()
pandl_2020["exp"] = budget2020_df_exp.groupby("Program")["Budgeted amount 2020"].sum()
pandl_2020["res-2020"] = pandl_2020["rev"] - pandl_2020["exp"]
pandl_2020.insert(0, 'Program', pandl_2020.index)
#pandl_2020 = pandl_2020.drop(columns=["rev", "exp"])

#2021
pandl_2021["rev"] = budget2021_df_rev.groupby("Program")["Budgeted amount 2021"].sum().abs()
pandl_2021["exp"] = budget2021_df_exp.groupby("Program")["Budgeted amount 2021"].sum()
pandl_2021["res-2021"] = pandl_2021["rev"] - pandl_2021["exp"]
pandl_2021.insert(0, 'Program', pandl_2021.index)
#pandl_2021 = pandl_2021.drop(columns=["rev", "exp"])

#2022
pandl_2022["rev"] = budget2022_df_rev.groupby("Program")["Budgeted amount 2022"].sum().abs()
pandl_2022["exp"] = budget2022_df_exp.groupby("Program")["Budgeted amount 2022"].sum()
pandl_2022["res-2022"] = pandl_2022["rev"] - pandl_2022["exp"]
pandl_2022.insert(0, 'Program', pandl_2022.index)
#pandl_2022 = pandl_2022.drop(columns=["rev", "exp"])

#2023
pandl_2023["rev"] = budget2023_df_rev.groupby("Program")["Budgeted amount 2023"].sum().abs()
pandl_2023["exp"] = budget2023_df_exp.groupby("Program")["Budgeted amount 2023"].sum()
pandl_2023["res-2023"] = pandl_2023["rev"] - pandl_2023["exp"]
pandl_2023.insert(0, 'Program', pandl_2023.index)
#pandl_2023 = pandl_2023.drop(columns=["rev", "exp"])

# pandl_timeline = pd.merge(pandl_2019, pandl_2020, on="Program", how="outer")
# pandl_timeline = pd.merge(pandl_timeline, pandl_2021, on="Program", how="outer")
# pandl_timeline = pd.merge(pandl_timeline, pandl_2022, on="Program", how="outer")
# pandl_timeline = pd.merge(pandl_timeline, pandl_2023, on="Program", how="outer")
# pandl_timeline["Acc 5 Years"] = pandl_timeline.sum(axis=1)
# pandl_timeline = pandl_timeline.sort_values("Acc 5 Years", ascending=False)
# pandl_timeline

# %%
db_list = [
    "pNl_program_2014",
    "pNl_program_2015",
    "pNl_program_2016",
    "pNl_program_2017",
    "pNl_program_2018",
    "pNl_program_2019",
    "pNl_program_2020",
    "pNl_program_2021",
    "pNl_program_2022",
    "pNl_program_2023"
          ]
df_to_db_list = [pandl_2014, pandl_2015, pandl_2016, pandl_2017, pandl_2018, pandl_2019, pandl_2020, pandl_2021, pandl_2022, pandl_2023]

from pymongo import MongoClient
from pprint import pprint

url = "mongodb+srv://city_toronto:project3@cluster0.gt72z8e.mongodb.net/"

# MongoDB Atlas connection details
connection_string = "mongodb+srv://city_toronto:project3@cluster0.gt72z8e.mongodb.net/"
database_name = 'city_toronto'

# Connect to MongoDB Atlas
client = MongoClient(connection_string)
db = client[database_name]

for i in range(0, len(df_to_db_list)):
    
    collection_name = db_list[i]
    
    if collection_name not in db.list_collection_names():
        db.create_collection(collection_name)

    collection = db[collection_name]

    #Clear current data
    collection.delete_many({})
    
    # Convert dataframe to dictionary format and insert into MongoDB
    data_dict = df_to_db_list[i].to_dict(orient='records')
    collection.insert_many(data_dict)
